# %%
# Import required libraries
import io
import keras
from matplotlib import pyplot as plt
from matplotlib.lines import Line2D
import numpy as np
import pandas as pd
import plotly.express as px
import dataclasses

# Load dataset
dataset_url = "https://raw.githubusercontent.com/stav1236/google-machine-learning-course/main/foundational-courses/2.machine-learning-crash-course/ml-models/classification/datasets/Score.csv"  # Update this path with the actual file
dateset = pd.read_csv(dataset_url)

@dataclasses.dataclass()
class ExperimentSettings:
  learning_rate: float
  number_epochs: int
  batch_size: int
  classification_threshold: float
  input_features: list[str]

@dataclasses.dataclass()
class Experiment:
  name: str
  settings: ExperimentSettings
  model: keras.Model
  epochs: np.ndarray
  metrics_history: keras.callbacks.History

def create_model(settings: ExperimentSettings, metrics: list[keras.metrics.Metric]) -> keras.Model:
  model_inputs = [keras.Input(name=feature, shape=(1,)) for feature in settings.input_features]
  concatenated_inputs = keras.layers.Concatenate()(model_inputs)
  dense = keras.layers.Dense(units=1, input_shape=(1,), activation=keras.activations.sigmoid)
  model_output = dense(concatenated_inputs)
  model = keras.Model(inputs=model_inputs, outputs=model_output)
  model.compile(
      optimizer=keras.optimizers.RMSprop(settings.learning_rate),
      loss=keras.losses.BinaryCrossentropy(),
      metrics=metrics,
  )
  return model

def train_model(experiment_name: str, model: keras.Model, dataset: pd.DataFrame, labels: np.ndarray, settings: ExperimentSettings) -> Experiment:
  features = {feature_name: np.array(dataset[feature_name]) for feature_name in settings.input_features}
  history = model.fit(x=features, y=labels, batch_size=settings.batch_size, epochs=settings.number_epochs)
  return Experiment(experiment_name, settings, model, history.epoch, pd.DataFrame(history.history))

# Evaluation
def evaluate_experiment(experiment: Experiment, test_dataset: pd.DataFrame, test_labels: np.array) -> dict[str, float]:
  features = {feature_name: np.array(test_dataset[feature_name]) for feature_name in experiment.settings.input_features}
  return experiment.model.evaluate(x=features, y=test_labels, batch_size=experiment.settings.batch_size, verbose=0, return_dict=True)

# Define experiment settings
settings = ExperimentSettings(
    learning_rate=0.001,
    number_epochs=60,
    batch_size=100,
    classification_threshold=0.35,
    input_features = [
    'Delay_from_due_date',
    'Num_of_Delayed_Payment',
    'Num_Credit_Inquiries',
    'Credit_Utilization_Ratio',
    'Credit_History_Age',
    'Amount_invested_monthly',
    'Monthly_Balance',
    'Age',
    'Annual_Income',
    'Num_Bank_Accounts',
    'Num_Credit_Card',
    'Interest_Rate',
    'Num_of_Loan',
    'Monthly_Inhand_Salary',
    'Changed_Credit_Limit',
    'Outstanding_Debt',
    'Total_EMI_per_month'
    ]
)

metrics = [
    keras.metrics.BinaryAccuracy(name='accuracy', threshold=settings.classification_threshold),
    keras.metrics.Precision(name='precision', thresholds=settings.classification_threshold),
    keras.metrics.Recall(name='recall', thresholds=settings.classification_threshold),
    keras.metrics.AUC(num_thresholds=100, name='auc'),
]

# Normalization
feature_mean = dateset.mean(numeric_only=True)
feature_std = dateset.std(numeric_only=True)
numerical_features = dateset.select_dtypes('number').columns
normalized_dataset = (dateset[numerical_features] - feature_mean) / feature_std
normalized_dataset['Is_Poor'] = (dateset['Credit_Score'] == "Poor")
normalized_dataset['Is_Standard'] = (dateset['Credit_Score'] == "Standard")
normalized_dataset['Is_Good'] = (dateset['Credit_Score'] == "Good")

# Splitting the dataset
number_samples = len(normalized_dataset)
index_80th = round(number_samples * 0.8)

shuffled_dataset = normalized_dataset.sample(frac=1, random_state=100)
train_data = shuffled_dataset.iloc[0:index_80th]
test_data = shuffled_dataset.iloc[index_80th:]

poor_vs_all_model = create_model(settings, metrics)
standart_vs_all_model = create_model(settings, metrics)
good_vs_all_model = create_model(settings, metrics)


experiment_poor_vs_all = train_model('baseline', poor_vs_all_model, train_data.drop(columns=['Is_Poor','Is_Standard','Is_Good']), train_data['Is_Poor'].to_numpy(), settings)
test_metrics_poor_vs_all = evaluate_experiment(experiment_poor_vs_all, test_data.drop(columns=['Is_Poor','Is_Standard','Is_Good']), test_data['Is_Poor'].to_numpy())

experiment_standard_vs_all = train_model('baseline', poor_vs_all_model, train_data.drop(columns=['Is_Poor','Is_Standard','Is_Good']), train_data['Is_Standard'].to_numpy(), settings)
test_metrics_standard_vs_all = evaluate_experiment(experiment_poor_vs_all, test_data.drop(columns=['Is_Poor','Is_Standard','Is_Good']), test_data['Is_Standard'].to_numpy())

experiment_good_vs_all = train_model('baseline', poor_vs_all_model, train_data.drop(columns=['Is_Poor','Is_Standard','Is_Good']), train_data['Is_Good'].to_numpy(), settings)
test_metrics_good_vs_all = evaluate_experiment(experiment_poor_vs_all, test_data.drop(columns=['Is_Poor','Is_Standard','Is_Good']), test_data['Is_Good'].to_numpy())
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6047 - auc: 0.7404 - loss: 0.6099 - precision: 0.4131 - recall: 0.8381
# Epoch 2/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7845 - auc: 0.8027 - loss: 0.4762 - precision: 0.6095 - recall: 0.7027
# Epoch 3/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7899 - auc: 0.7997 - loss: 0.4746 - precision: 0.6310 - recall: 0.6626
# Epoch 4/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7931 - auc: 0.8037 - loss: 0.4699 - precision: 0.6342 - recall: 0.6627
# Epoch 5/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7899 - auc: 0.8009 - loss: 0.4726 - precision: 0.6300 - recall: 0.6535
# Epoch 6/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7922 - auc: 0.8054 - loss: 0.4693 - precision: 0.6345 - recall: 0.6645
# Epoch 7/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7919 - auc: 0.8021 - loss: 0.4709 - precision: 0.6318 - recall: 0.6591
# Epoch 8/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7904 - auc: 0.8031 - loss: 0.4720 - precision: 0.6319 - recall: 0.6618
# Epoch 9/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7919 - auc: 0.8038 - loss: 0.4700 - precision: 0.6320 - recall: 0.6618
# Epoch 10/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7902 - auc: 0.7995 - loss: 0.4740 - precision: 0.6315 - recall: 0.6560
# Epoch 11/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7894 - auc: 0.8006 - loss: 0.4728 - precision: 0.6284 - recall: 0.6530
# Epoch 12/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7924 - auc: 0.8048 - loss: 0.4688 - precision: 0.6333 - recall: 0.6640
# Epoch 13/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7901 - auc: 0.8034 - loss: 0.4725 - precision: 0.6333 - recall: 0.6590
# Epoch 14/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7914 - auc: 0.8006 - loss: 0.4737 - precision: 0.6352 - recall: 0.6581
# Epoch 15/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7919 - auc: 0.8023 - loss: 0.4725 - precision: 0.6372 - recall: 0.6623
# Epoch 16/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7905 - auc: 0.7998 - loss: 0.4723 - precision: 0.6305 - recall: 0.6546
# Epoch 17/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7908 - auc: 0.8018 - loss: 0.4726 - precision: 0.6328 - recall: 0.6624
# Epoch 18/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7903 - auc: 0.8024 - loss: 0.4721 - precision: 0.6323 - recall: 0.6634
# Epoch 19/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.
60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8336 - auc: 0.8515 - loss: 0.3449 - precision: 0.5327 - recall: 0.5960
# Epoch 25/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8340 - auc: 0.8503 - loss: 0.3456 - precision: 0.5330 - recall: 0.5872
# Epoch 26/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8338 - auc: 0.8559 - loss: 0.3408 - precision: 0.5340 - recall: 0.5995
# Epoch 27/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8330 - auc: 0.8511 - loss: 0.3450 - precision: 0.5318 - recall: 0.5904
# Epoch 28/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8341 - auc: 0.8533 - loss: 0.3414 - precision: 0.5317 - recall: 0.5939
# Epoch 29/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8326 - auc: 0.8510 - loss: 0.3443 - precision: 0.5293 - recall: 0.5831
# Epoch 30/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8316 - auc: 0.8535 - loss: 0.3459 - precision: 0.5342 - recall: 0.5991
# Epoch 31/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8333 - auc: 0.8523 - loss: 0.3449 - precision: 0.5349 - recall: 0.5912
# Epoch 32/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8331 - auc: 0.8527 - loss: 0.3440 - precision: 0.5321 - recall: 0.6005
# Epoch 33/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8309 - auc: 0.8510 - loss: 0.3454 - precision: 0.5282 - recall: 0.5866
# Epoch 34/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8331 - auc: 0.8505 - loss: 0.3460 - precision: 0.5322 - recall: 0.5911
# Epoch 35/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8305 - auc: 0.8515 - loss: 0.3448 - precision: 0.5266 - recall: 0.5906
# Epoch 36/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8327 - auc: 0.8494 - loss: 0.3457 - precision: 0.5292 - recall: 0.5769
# Epoch 37/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8326 - auc: 0.8499 - loss: 0.3444 - precision: 0.5273 - recall: 0.5865
# Epoch 38/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8337 - auc: 0.8534 - loss: 0.3444 - precision: 0.5359 - recall: 0.5978
# Epoch 39/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8348 - auc: 0.8549 - loss: 0.3424 - precision: 0.5388 - recall: 0.5964
# Epoch 40/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8323 - auc: 0.8523 - loss: 0.3441 - precision: 0.5306 - recall: 0.5919
# Epoch 41/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8323 - auc: 0.8529 - loss: 0.3429 - precision: 0.5283 - recall: 0.5977
# Epoch 42/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8329 - auc: 0.8530 - loss: 0.3431 - precision: 0.5300 - recall: 0.5922
# Epoch 43/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8330 - auc: 0.8532 - loss: 0.3413 - precision: 0.5263 - recall: 0.6004
# Epoch 44/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8327 - auc: 0.8529 - loss: 0.3444 - precision: 0.5336 - recall: 0.5999
# Epoch 45/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8328 - auc: 0.8512 - loss: 0.3450 - precision: 0.5314 - recall: 0.5919
# Epoch 46/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8333 - auc: 0.8507 - loss: 0.3451 - precision: 0.5314 - recall: 0.5831
# Epoch 47/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8334 - auc: 0.8553 - loss: 0.3403 - precision: 0.5305 - recall: 0.5980
# Epoch 48/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8329 - auc: 0.8517 - loss: 0.3424 - precision: 0.5265 - recall: 0.5874
# Epoch 49/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8353 - auc: 0.8544 - loss: 0.3416 - precision: 0.5352 - recall: 0.6015
# Epoch 50/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8280 - auc: 0.8520 - loss: 0.3472 - precision: 0.5268 - recall: 0.5962
# Epoch 51/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8343 - auc: 0.8522 - loss: 0.3428 - precision: 0.5321 - recall: 0.5818
# Epoch 52/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8320 - auc: 0.8521 - loss: 0.3453 - precision: 0.5322 - recall: 0.6005
# Epoch 53/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8316 - auc: 0.8518 - loss: 0.3466 - precision: 0.5323 - recall: 0.5890
# Epoch 54/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8323 - auc: 0.8518 - loss: 0.3471 - precision: 0.5358 - recall: 0.5905
# Epoch 55/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8325 - auc: 0.8477 - loss: 0.3457 - precision: 0.5246 - recall: 0.5730
# Epoch 56/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8311 - auc: 0.8526 - loss: 0.3453 - precision: 0.5296 - recall: 0.5948
# Epoch 57/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8323 - auc: 0.8516 - loss: 0.3428 - precision: 0.5263 - recall: 0.5799
# Epoch 58/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8351 - auc: 0.8524 - loss: 0.3446 - precision: 0.5376 - recall: 0.5939
# Epoch 59/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8314 - auc: 0.8534 - loss: 0.3421 - precision: 0.5261 - recall: 0.5928
# Epoch 60/60
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8329 - auc: 0.8492 - loss: 0.3448 - precision: 0.5274 - recall: 0.5821

# %%
# Predict and classify entire dataset
features = {feature_name: np.array(normalized_dataset[feature_name]) for feature_name in settings.input_features}

prob_poor = poor_vs_all_model.predict(features).flatten()
prob_standard = standart_vs_all_model.predict(features).flatten()
prob_good = good_vs_all_model.predict(features).flatten()

predictions_df = pd.DataFrame({
    'Poor_Prob': prob_poor,
    'Standard_Prob': prob_standard,
    'Good_Prob': prob_good
})

predictions_df['Predicted_Credit_Score'] = predictions_df[['Poor_Prob', 'Standard_Prob', 'Good_Prob']].idxmax(axis=1)
predictions_df['Predicted_Credit_Score'] = predictions_df['Predicted_Credit_Score'].replace({
    'Poor_Prob': 'Poor',
    'Standard_Prob': 'Standard',
    'Good_Prob': 'Good'
})
# Out:
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 17s 6ms/step
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step

# %%
# # Predict and classify entire dataset
# features = {feature_name: np.array(normalized_dataset[feature_name]) for feature_name in settings.input_features}

# prob_poor = experiment_poor_vs_all.model.predict(features).flatten()
# prob_standard = experiment_standard_vs_all.model.predict(features).flatten()
# prob_good = experiment_good_vs_all.model.predict(features).flatten()

# predictions_df = pd.DataFrame({
#     'Poor_Prob': prob_poor,
#     'Standard_Prob': prob_standard,
#     'Good_Prob': prob_good
# })

# predictions_df['Predicted_Credit_Score'] = predictions_df[['Poor_Prob', 'Standard_Prob', 'Good_Prob']].idxmax(axis=1)
# predictions_df['Predicted_Credit_Score'] = predictions_df['Predicted_Credit_Score'].replace({
#     'Poor_Prob': 'Poor',
#     'Standard_Prob': 'Standard',
#     'Good_Prob': 'Good'
# })
# Out:
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# 3124/3124 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step

# %%
# Instead of using ace_tools, use the display function from IPython.display
# This is a standard library and doesn't require any external installation.
from IPython.display import display

# Display the predictions
display(predictions_df.sample(frac=1))
# Out:
#        Poor_Prob  Standard_Prob  Good_Prob Predicted_Credit_Score
# 2742    0.005891       0.653431   0.587736               Standard
# 14852   0.395870       0.086109   0.415764                   Good
# 67468   0.207480       0.079045   0.313636                   Good
# 73744   0.019059       0.703120   0.521184               Standard
# 94743   0.001817       0.739185   0.156923               Standard
# ...          ...            ...        ...                    ...
# 19508   0.128104       0.884804   0.644673               Standard
# 31853   0.129754       0.869944   0.677440               Standard
# 22005   0.008631       0.246557   0.403464                   Good
# 93158   0.008936       0.729656   0.414965               Standard
# 39217   0.254955       0.572319   0.461676               Standard
#
# [99960 rows x 4 columns]

# %%
from sklearn.metrics import accuracy_score, classification_report
# Calculate accuracy
true_labels = dateset['Credit_Score']
predicted_labels = predictions_df['Predicted_Credit_Score']
accuracy = accuracy_score(true_labels, predicted_labels)
print(f"Model Accuracy: {accuracy:.4f}")
# Out:
# Model Accuracy: 0.3629
